# %%
import os
import xml.etree.ElementTree as ET

# Paths
xml_folder = "APS360_Project_Dataset/dataset2/Annotations"
output_folder = "APS360_Project_Dataset/dataset2/labels"

# Create the output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# Function to convert XML to YOLO format
def convert_to_yolo(xml_file, output_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    # Get image dimensions
    width = int(root.find("size/width").text)
    height = int(root.find("size/height").text)
    
    with open(output_file, "w") as f:
        for obj in root.findall("object"):
            # Assuming class_id is 0 since you only have one class (card number region)
            class_id = 0
            
            # Get bounding box coordinates
            xmin = int(obj.find("bndbox/xmin").text)
            ymin = int(obj.find("bndbox/ymin").text)
            xmax = int(obj.find("bndbox/xmax").text)
            ymax = int(obj.find("bndbox/ymax").text)
            
            # Convert to YOLO format
            x_center = (xmin + xmax) / 2 / width
            y_center = (ymin + ymax) / 2 / height
            box_width = (xmax - xmin) / width
            box_height = (ymax - ymin) / height
            
            # Write to the file
            f.write(f"{class_id} {x_center} {y_center} {box_width} {box_height}\n")

# Convert each XML file
for xml_file in os.listdir(xml_folder):
    if xml_file.endswith(".xml"):
        input_path = os.path.join(xml_folder, xml_file)
        output_path = os.path.join(output_folder, xml_file.replace(".xml", ".txt"))
        convert_to_yolo(input_path, output_path)

# %%
import os
import shutil
import random

# Paths
image_folder = "APS360_Project_Dataset/dataset2/JPEGImages"
label_folder = "APS360_Project_Dataset/dataset2/labels"
train_image_folder = "APS360_Project_Dataset/dataset2/images/train"
val_image_folder = "APS360_Project_Dataset/dataset2/images/val"
test_image_folder = "APS360_Project_Dataset/dataset2/images/test"
train_label_folder = "APS360_Project_Dataset/dataset2/labels/train"
val_label_folder = "APS360_Project_Dataset/dataset2/labels/val"
test_label_folder = "APS360_Project_Dataset/dataset2/labels/test"

# Create the folders if they don't exist
os.makedirs(train_image_folder, exist_ok=True)
os.makedirs(val_image_folder, exist_ok=True)
os.makedirs(test_image_folder, exist_ok=True)
os.makedirs(train_label_folder, exist_ok=True)
os.makedirs(val_label_folder, exist_ok=True)
os.makedirs(test_label_folder, exist_ok=True)

# Get a list of image files and shuffle
image_files = [f for f in os.listdir(image_folder) if f.endswith(".jpg")]
random.shuffle(image_files)

# Set the split ratios
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# Calculate the number of images for each set
train_count = int(len(image_files) * train_ratio)
val_count = int(len(image_files) * val_ratio)

# Split and move files
for i, image_file in enumerate(image_files):
    base_filename = os.path.splitext(image_file)[0]
    label_file = base_filename + ".txt"
    
    # Check if the label file exists before moving
    if not os.path.exists(os.path.join(label_folder, label_file)):
        print(f"Warning: Label file {label_file} not found for image {image_file}. Skipping.")
        continue
    
    # Determine the target folders based on the split
    if i < train_count:
        target_image_folder = train_image_folder
        target_label_folder = train_label_folder
    elif i < train_count + val_count:
        target_image_folder = val_image_folder
        target_label_folder = val_label_folder
    else:
        target_image_folder = test_image_folder
        target_label_folder = test_label_folder

    # Copy image and label files to their respective folders
    shutil.copy(os.path.join(image_folder, image_file), os.path.join(target_image_folder, image_file))
    shutil.copy(os.path.join(label_folder, label_file), os.path.join(target_label_folder, label_file))
# Out:
# Copying 1758.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 121.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1352.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 412.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 434.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 18.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 862.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 35.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 48.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 840.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1261.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 189.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1093.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 398.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 470.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 200.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 589.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 675.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 525.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 63.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1856.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 625.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1956.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 601.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1058.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 113.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 175.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 345.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 69.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2147.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1849.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1169.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1541.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1123.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 392.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1857.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 94.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 938.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1653.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1496.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 254.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1987.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1481.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 460.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2122.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1743.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 618.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 210.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1680.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1723.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 493.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1021.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1640.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 834.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1672.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1603.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 6.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1741.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 575.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 817.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1360.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2061.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 905.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1212.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 606.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1475.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 850.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 92.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 863.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1994.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1789.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1706.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 146.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1045.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 560.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1781.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 711.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1048.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 209.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 761.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1432.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 678.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1353.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1628.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 538.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1763.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1178.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 960.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 15.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 366.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 873.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1100.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 110.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1587.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 745.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 855.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1894.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 98.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 586.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 799.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1560.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1685.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 258.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1643.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 623.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 79.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1779.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 921.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 38.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1254.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1141.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1378.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 267.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 617.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1609.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 728.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 75.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1072.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 377.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 106.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 64.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1457.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1465.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 902.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 370.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 984.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1288.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 971.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 400.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 766.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2085.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 669.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1732.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2081.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 177.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 787.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1176.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1287.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1085.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 51.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 202.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1293.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1037.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 903.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 926.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2136.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 718.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1825.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2089.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1533.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 498.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 240.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 151.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1879.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1839.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1724.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1661.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 578.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1491.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 463.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 505.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 239.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1611.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1645.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1904.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2008.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1476.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 536.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1024.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1330.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 784.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2096.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2101.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 236.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1431.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 699.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 300.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2103.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 413.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 428.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1342.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 39.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 163.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1507.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 640.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1590.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1552.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1916.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 90.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1631.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 171.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1335.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 861.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1166.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 137.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1157.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1189.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 662.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2148.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1363.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 740.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 186.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1751.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1460.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2159.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 492.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1816.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1187.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1181.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 769.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 422.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1618.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1903.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 944.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2013.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 743.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1172.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 729.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 170.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 181.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 480.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1442.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1304.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1881.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 870.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2012.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1614.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1807.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1017.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2003.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1990.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1964.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1086.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 401.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2028.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1323.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1339.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 679.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 934.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 357.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1729.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1139.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 30.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1397.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 29.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 273.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 785.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 621.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 16.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 937.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 508.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1592.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1635.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1455.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1054.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1962.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 500.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1260.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1151.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1044.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2076.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1922.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 307.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 355.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 845.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1759.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1033.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1297.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1003.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2038.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1719.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1422.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1725.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1950.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 335.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1190.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 115.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 720.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1947.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1336.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1939.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 466.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 160.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1845.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1201.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 207.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 367.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 429.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 614.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 108.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 4.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1198.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1167.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 424.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1852.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 497.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 683.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 641.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 580.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 691.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 120.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1525.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 800.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1094.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1047.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 832.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1489.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1488.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 414.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1948.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1608.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 418.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 244.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1823.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 158.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 572.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 853.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 568.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1014.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 739.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 532.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1968.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1473.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1281.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1815.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 707.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 894.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1193.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 484.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1543.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2053.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1583.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 563.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 636.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1921.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 819.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 719.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2121.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 588.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 767.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 824.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1075.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 786.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1394.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2050.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1715.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1873.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2113.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1568.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 256.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2015.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 215.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1636.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 758.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1629.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 406.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 515.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1409.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 667.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1365.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 540.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 56.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1782.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 773.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1049.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1757.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 912.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 285.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1793.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1668.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1595.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 145.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1109.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 472.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 299.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1023.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 715.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 693.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 604.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 827.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 457.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1063.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1937.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1380.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2123.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 8.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 997.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1385.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1913.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1495.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 453.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2092.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 793.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1008.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1993.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1977.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1940.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 297.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 946.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 302.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 648.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 74.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1148.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2155.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1919.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1404.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 731.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 957.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1848.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2001.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1421.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 541.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 391.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 9.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1906.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 327.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 748.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 365.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1026.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 93.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2051.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 775.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1624.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1019.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 61.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 295.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2098.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1101.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1841.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 797.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1430.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 438.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1778.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1082.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 290.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1204.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1192.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1345.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1500.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1519.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1132.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1630.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 919.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1232.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1215.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1222.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1249.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1214.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2058.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1368.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1791.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1899.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 358.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1364.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1923.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1467.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1982.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1796.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1788.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2091.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 223.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1545.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 899.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1772.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1389.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 920.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 142.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1837.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1087.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 475.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 399.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1300.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1207.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2128.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 551.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1458.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 319.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1826.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1245.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1466.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 70.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1405.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1610.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2067.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1655.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1487.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 411.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 204.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2029.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 633.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 547.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 558.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 829.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 806.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 994.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 272.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1143.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1790.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 647.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 287.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 7.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 552.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1688.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2026.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1159.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 168.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 733.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2108.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2095.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 449.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1004.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 925.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 931.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2062.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1573.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 37.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 105.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 517.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 375.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1986.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2090.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 257.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2035.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 537.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1870.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1434.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 881.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 59.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1005.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1471.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 620.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1783.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1843.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1168.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2138.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 736.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1664.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1478.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 918.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1898.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1951.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1565.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1864.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2032.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 129.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 385.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1407.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 619.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1665.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 415.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 924.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1679.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 372.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 446.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 535.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 265.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1644.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 577.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 55.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2019.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 109.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1954.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1259.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1242.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1554.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1516.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1410.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1753.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 28.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1498.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1126.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2025.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 998.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2066.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1456.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1354.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 746.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 368.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2093.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 851.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1291.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1774.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 523.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2073.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 856.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2084.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1474.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 665.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1890.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1677.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 958.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1820.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 230.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1012.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1580.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 780.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1165.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 927.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1958.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 459.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 710.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 458.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1453.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 468.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 520.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1859.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1854.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 432.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1599.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1925.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1315.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1186.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 381.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1742.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 33.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 544.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 292.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 828.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 384.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 531.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 768.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1327.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1337.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 996.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1420.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 331.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1529.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1244.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 778.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 284.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1156.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1217.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 444.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 857.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 789.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2151.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1585.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1084.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 666.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1438.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1777.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 86.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1372.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 764.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1548.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1681.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1497.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1332.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 704.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2065.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1521.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 792.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1163.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1632.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 394.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 156.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 571.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1022.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1605.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2020.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2034.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1690.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 17.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1687.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1257.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1540.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1120.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 32.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 674.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 809.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 234.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1387.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1053.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1840.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 722.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 352.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1276.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2156.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 622.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1459.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1097.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 203.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 890.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 730.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 462.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 251.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1119.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2027.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1579.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2119.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1227.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1716.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 43.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 598.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 104.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 378.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2075.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1747.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1973.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1804.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2158.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 660.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1454.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1684.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1248.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1036.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1700.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 803.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 329.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1818.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 616.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 495.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1880.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 888.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1343.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1792.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2124.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1278.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1878.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 72.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 310.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 992.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1872.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1357.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 126.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1007.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1567.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 373.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1020.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 712.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1933.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1604.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 573.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 218.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1625.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1972.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1359.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2160.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 77.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 2137.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 334.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 512.jpg to APS360_Project_Dataset/dataset2/images/train
# Copying 1310.jpg to APS360_Project_Dataset/dataset2/images/train
# ...
# Copying 1218.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 842.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1941.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1830.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1935.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1071.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 914.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1450.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2088.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 813.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1326.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1322.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1936.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 776.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1050.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 338.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1105.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1978.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1530.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2109.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1499.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 788.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1806.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1702.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1419.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 275.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 875.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2046.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 522.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1896.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1344.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2143.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2071.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1079.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1308.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 278.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1373.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 62.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1312.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1320.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1013.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 322.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 313.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 479.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1418.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1667.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 281.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1709.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 524.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 610.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 227.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1817.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1701.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1651.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1895.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 542.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 676.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 753.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1136.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1946.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 467.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1340.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1892.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1891.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1524.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 798.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 96.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1137.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2030.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1182.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 336.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 248.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1092.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1280.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1375.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 847.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1472.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1663.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1733.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1787.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 471.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 451.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 727.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 609.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 435.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1945.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 570.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1001.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 282.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1313.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1600.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1669.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1470.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 976.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 183.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 759.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1984.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 713.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 886.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1801.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 73.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1828.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 681.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1425.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1536.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 654.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1760.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1279.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 574.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1319.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 942.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2005.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 808.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 644.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1756.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1542.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 503.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 410.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 611.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1865.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1650.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 839.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1989.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 990.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1369.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1514.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1511.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 155.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 131.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1959.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1658.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 725.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1535.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 659.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1429.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 71.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 952.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 961.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1173.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 270.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2139.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1510.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1752.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1088.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1867.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1142.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1819.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 502.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 247.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2042.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1402.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 506.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 883.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 518.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 354.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1252.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 978.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1301.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 116.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1124.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 216.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1574.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2031.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2086.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 192.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1976.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 259.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 20.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1355.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 150.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 416.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 433.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1800.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1691.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1234.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 450.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1298.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2023.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 97.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 891.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1446.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 176.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 405.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 643.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 496.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 749.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 448.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1557.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 124.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 779.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1271.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 576.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 732.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1686.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 350.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 859.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1785.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 408.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 118.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1534.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 67.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 337.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 846.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1311.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 298.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 661.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1480.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1808.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 818.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1662.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1813.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 241.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 956.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 308.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1713.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1835.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 132.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1154.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 959.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 658.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 651.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 587.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1748.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 567.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2110.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2040.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1876.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 865.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1371.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 974.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1235.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 509.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1703.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 143.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2016.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1433.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 409.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2107.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1674.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1379.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 49.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 486.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 101.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2017.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 57.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1398.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 915.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 825.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 1682.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2010.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 36.jpg to APS360_Project_Dataset/dataset2/images/test
# Copying 2063.jpg to APS360_Project_Dataset/dataset2/images/test
